# %%
import pandas as pd
import os
import json

# %%
Q = []
A = []

lst = os.listdir()
full_dirs = [s for s in lst if '멀티모달' in s]

for part in full_dirs:
    for dir in dir_lst:
        path = part + '/' + dir
        filenames = os.listdir(path)
        
        find_word = '_interpolation.json'
        lst = [s for s in filenames if find_word in s]
        
        filename = min(lst, key=len)
        with open(path + '/' + filename, 'r', encoding='utf-8') as f:
            json_object = json.loads(f.read())
        
        st_time = {}
        for idx, dialog in enumerate(json_object['dialogue_infos']):
            st_time[idx] = dialog['start_time']
        sort_time = sorted(st_time.items(), key = lambda item: item[1])
        sort_time = [i[0] for i in sort_time]

        for i in range(len(sort_time)):
            try:
                now = sort_time[i]
                next = sort_time[i+1]
                Q.append(json_object['dialogue_infos'][now]['utterance'])
                A.append(json_object['dialogue_infos'][next]['utterance'])
            except:
                pass

# %%
script = pd.DataFrame([Q, A]).T
script.columns = ['Q','A']
script
# Out:
#                                                      Q  \
# 0                                            지금 뭐하는거야?
# 1                                 형 얼굴에 맞는 배경음악 깔아준거야.
# 2                                            뭐? 에휴 진짜.
# 3    에휴 진짜. 아무리 여자때문에 심란해도 간만에 여행와서 꼭 그렇게 계속 죽상만 쓰고...
# 4                                     뭐 소름끼치게 오래되긴 했네.
# ..                                                 ...
# 924                        이사님. 저 한 번만 더 기회를 주시면 안될까요?
# 925                                                 뭐?
# 926  신제품 일 맡겨주세요. 저 진짜 잘할 자신 있어요. 어, 이사님도 그러셨잖아요. 이...
# 927  이사장. 남초주류업계에서 여자인 내가 이 자리까지 올라오기 쉬웠을 것 같아? 나한텐...
# 928  걱정하지마세요. 저 혼자몸일때보다 더 열심히 더 절박하게 할게요. 이사님께서 조금만...
#
#                                                      A
# 0                                 형 얼굴에 맞는 배경음악 깔아준거야.
# 1                                            뭐? 에휴 진짜.
# 2    에휴 진짜. 아무리 여자때문에 심란해도 간만에 여행와서 꼭 그렇게 계속 죽상만 쓰고...
# 3                                     뭐 소름끼치게 오래되긴 했네.
# 4          그니까 어? 야 좀 웃어라 웃어. 아 그런 의미에서 우리 인증샷 하나 찍을까?
# ..                                                 ...
# 924                                                 뭐?
# 925  신제품 일 맡겨주세요. 저 진짜 잘할 자신 있어요. 어, 이사님도 그러셨잖아요. 이...
# 926  이사장. 남초주류업계에서 여자인 내가 이 자리까지 올라오기 쉬웠을 것 같아? 나한텐...
# 927  걱정하지마세요. 저 혼자몸일때보다 더 열심히 더 절박하게 할게요. 이사님께서 조금만...
# 928  그 배려는 사회가 할 몫이지 내 의무는 아니지않나? 유감이야. 남잔 일을 할지 애를...
#
# [929 rows x 2 columns]

# %%
script.to_csv('script_part_5.csv', encoding='utf-8', index=False)
